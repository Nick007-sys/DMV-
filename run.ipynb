# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Companies_dataset.csv')

# %%
df.describe()
# Out:
#         Unnamed: 0    ratings
# count    30.000000  30.000000
# mean   4407.533333   3.946667
# std    2810.407514   0.311540
# min     268.000000   3.300000
# 25%    1863.750000   3.800000
# 50%    4270.000000   4.000000
# 75%    7021.000000   4.175000
# max    8767.000000   4.600000

# %%
df.head()
# Out:
#    Unnamed: 0                 name  ratings   review_count              ctype  \
# 0        7958  Farmson Pharmace...      3.4   (76 Reviews)  Vadodara + 5 more
# 1        5118              SEForge      3.6  (121 Reviews)            Private
# 2        8613  Kalinga Universi...      3.4   (70 Reviews)    Raipur + 7 more
# 3         764              Tenneco      3.8  (754 Reviews)            Private
# 4        5265             Toyo INK      4.2  (117 Reviews)            Private
#
#                        years                              hq  \
# 0   501-1k Employees (India)                    53 years old
# 1               17 years old             Coimbatore + 4 more
# 2  201-500 Employees (India)                    10 years old
# 3               83 years old  Lake Forest,Illinois + 28 more
# 4               17 years old                  Tokyo + 9 more
#
#                    employees
# 0                        NaN
# 1  201-500 Employees (India)
# 2                        NaN
# 3    1k-5k Employees (India)
# 4    11-50 Employees (India)

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (30, 8)
# Index(['Unnamed: 0', 'name', 'ratings', 'review_count', 'ctype', 'years', 'hq',
#        'employees'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30 non-null     int64
#  1   name          30 non-null     object
#  2   ratings       30 non-null     float64
#  3   review_count  30 non-null     object
#  4   ctype         30 non-null     object
#  5   years         27 non-null     object
#  6   hq            29 non-null     object
#  7   employees     19 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ KB
# None

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('Companies_dataset.csv')

# Randomly sample 30 rows
df_sample = df.sample(n=30, random_state=42)

# Reset index (optional, cleaner output)
df_sample = df_sample.reset_index(drop=True)

# Save to new CSV
df_sample.to_csv('Companies_dataset.csv', index=False)

print("New dataset with 30 rows saved successfully!")
# Out:
# New dataset with 30 rows saved successfully!

# %%
df=pd.read_csv('Companies_dataset.csv')

# %%
print(df.shape)
print(df.columns)
print(df.info())
# Out:
# (30, 8)
# Index(['Unnamed: 0', 'name', 'ratings', 'review_count', 'ctype', 'years', 'hq',
#        'employees'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30 non-null     int64
#  1   name          30 non-null     object
#  2   ratings       30 non-null     float64
#  3   review_count  30 non-null     object
#  4   ctype         30 non-null     object
#  5   years         27 non-null     object
#  6   hq            29 non-null     object
#  7   employees     19 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.0+ KB
# None

# %%
df.head()
# Out:
#    Unnamed: 0                 name  ratings    review_count  \
# 0         268           S&P Global      4.2  (1.8k Reviews)
# 1         512  Mercedes-Benz Re...      4.0  (1.1k Reviews)
# 2        8520  Kifs Housing Fin...      3.6    (70 Reviews)
# 3        2898             Algonomy      3.9   (212 Reviews)
# 4        8767     Eurofins Advinus      3.8    (68 Reviews)
#
#                 ctype                     years  \
# 0              Public             106 years old
# 1              Public              27 years old
# 2             Private               8 years old
# 3             Private              19 years old
# 4  Bengaluru + 2 more  501-1k Employees (India)
#
#                                         hq                  employees
# 0         New York City,New York + 17 more   5k-10k Employees (India)
# 1  Bengaluru/Bangalore,Karnataka + 48 more   5k-10k Employees (India)
# 2                      Ahmedabad + 30 more   51-200 Employees (India)
# 3             Bangalore,Karnataka + 8 more  201-500 Employees (India)
# 4                             18 years old                        NaN

# %%
df['review_count'] = df['review_count'].str.replace(r'[^0-9]', '', regex=True)
df['review_count'] = pd.to_numeric(df['review_count'], errors='coerce')

# %%
df['years'] = df['years'].str.extract(r'(\d+)')
df['years'] = pd.to_numeric(df['years'], errors='coerce')

# %%
print(df)
# Out:
#     Unnamed: 0                 name  ratings  review_count  \
# 0          268           S&P Global      4.2            18
# 1          512  Mercedes-Benz Re...      4.0            11
# 2         8520  Kifs Housing Fin...      3.6            70
# 3         2898             Algonomy      3.9           212
# 4         8767     Eurofins Advinus      3.8            68
# 5         3018     Religare Finvest      4.6           204
# 6         3033  Titan Laboratori...      3.7           203
# 7         4300             Ican BPO      4.5           144
# 8         7268  Manav Rachna Int...      3.9            84
# 9         7958  Farmson Pharmace...      3.4            76
# 10        5265             Toyo INK      4.2           117
# 11        2292  Applied Material...      4.1           264
# 12        8494       Vtc Tradewings      4.0            71
# 13        4240        Ambit Finvest      4.1           147
# 14        7285       Delux Bearings      4.1            84
# 15        6111  High Court Luckn...      4.4           101
# 16        5118              SEForge      3.6           121
# 17        8613  Kalinga Universi...      3.4            70
# 18        3464      Damco Solutions      3.3           179
# 19         764              Tenneco      3.8           754
# 20        6280  Ministry of Home...      4.2            98
# 21        2549  adani power maha...      3.8           240
# 22        1721  Vedang Cellular ...      4.2           349
# 23        5286  Smiiel - A Unit ...      3.7           116
# 24        5555  Global Opportuni...      3.9           110
# 25         737  Sahara India Par...      3.8           783
# 26        1128   Collins Aerospa...      4.0           517
# 27        1513             DP World      4.0           397
# 28        1514  Offshore Infrast...      4.2           397
# 29        7755  VOLTECH O AND M ...      4.0            78
#
#                  ctype  years                                       hq  \
# 0               Public  106.0         New York City,New York + 17 more
# 1               Public   27.0  Bengaluru/Bangalore,Karnataka + 48 more
# 2              Private    8.0                      Ahmedabad + 30 more
# 3              Private   19.0             Bangalore,Karnataka + 8 more
# 4   Bengaluru + 2 more  501.0                             18 years old
# 5               Public   17.0                Delhi/NCR,Delhi + 31 more
# 6              Private   19.0             Mumbai,Maharashtra + 11 more
# 7              Private   14.0                           Thane + 2 more
# 8   Faridabad + 2 more  501.0                             26 years old
# 9    Vadodara + 5 more  501.0                             53 years old
# 10             Private   17.0                           Tokyo + 9 more
# 11             Private   21.0          Santa Clara,California + 9 more
# 12             Private   54.0                     Chandigarh + 14 more
# 13    Mumbai + 39 more    NaN                 51-200 Employees (India)
# 14     Mumbai + 8 more  501.0                             67 years old
# 15   Lucknow + 17 more    NaN               201-500 Employees (Global)
# 16             Private   17.0                      Coimbatore + 4 more
# 17     Raipur + 7 more  201.0                             10 years old
# 18             Private   27.0           Princeton,New Jersey + 15 more
# 19             Private   83.0           Lake Forest,Illinois + 28 more
# 20             Private   76.0                      New Delhi + 12 more
# 21    Mundra + 13 more    NaN                                      NaN
# 22    Mumbai + 48 more  501.0                             13 years old
# 23      Noida + 2 more   51.0                             28 years old
# 24             Private   22.0                Delhi/NCR,Delhi + 12 more
# 25             Private   45.0         Lucknow,Uttar Pradesh + 207 more
# 26             Private    5.0        Charlotte,North Carolina + 4 more
# 27              Public   18.0                Dubai,Jebel Ali + 40 more
# 28             Private   28.0             Mumbai,Maharashtra + 34 more
# 29   Chennai + 15 more   11.0                             14 years old
#
#                     employees
# 0    5k-10k Employees (India)
# 1    5k-10k Employees (India)
# 2    51-200 Employees (India)
# 3   201-500 Employees (India)
# 4                         NaN
# 5     1k-5k Employees (India)
# 6   201-500 Employees (India)
# 7   201-500 Employees (India)
# 8                         NaN
# 9                         NaN
# 10    11-50 Employees (India)
# 11    1k-5k Employees (India)
# 12   51-200 Employees (India)
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16  201-500 Employees (India)
# 17                        NaN
# 18   501-1k Employees (India)
# 19    1k-5k Employees (India)
# 20   51-200 Employees (India)
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24   51-200 Employees (India)
# 25   5k-10k Employees (India)
# 26    1k-5k Employees (India)
# 27    1k-5k Employees (India)
# 28   501-1k Employees (India)
# 29                        NaN

# %%
df = df.drop(index=29)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# name             0
# ratings          0
# review_count     0
# ctype            0
# years            3
# hq               1
# employees       10
# dtype: int64

# %%
def fix_row(row):
    # Fix misplaced years
    if isinstance(row['hq'], str) and 'years old' in row['hq']:
        row['years'] = row['hq'].split()[0]
        row['hq'] = None

    # Fix misplaced employees
    if isinstance(row['hq'], str) and 'Employees' in row['hq']:
        row['employees'] = row['hq']
        row['hq'] = None

    return row

df = df.apply(fix_row, axis=1)

# %%
df['years'] = df['years'].astype(str).str.extract(r'(\d+)')
df['years'] = pd.to_numeric(df['years'], errors='coerce')

# %%
def clean_employees(val):
    if pd.isna(val):
        return None

    val = str(val).lower().replace(',', '').strip()

    # Handle "lakh"
    if 'lakh' in val:
        return 100000

    # Handle ranges like "1k-5k"
    if '-' in val:
        parts = val.split(' ')[0].split('-')

        def convert(x):
            if 'k' in x:
                return float(x.replace('k','')) * 1000
            else:
                return float(x)

        try:
            return (convert(parts[0]) + convert(parts[1])) / 2
        except:
            return None

    # Handle single values like "50k"
    if 'k' in val:
        try:
            return float(val.replace('k','')) * 1000
        except:
            return None

    return None

# %%
df['employees_clean'] = df['employees'].apply(clean_employees)

# %%
df
# Out:
#     Unnamed: 0                 name  ratings  review_count  \
# 0          268           S&P Global      4.2            18
# 1          512  Mercedes-Benz Re...      4.0            11
# 2         8520  Kifs Housing Fin...      3.6            70
# 3         2898             Algonomy      3.9           212
# 4         8767     Eurofins Advinus      3.8            68
# 5         3018     Religare Finvest      4.6           204
# 6         3033  Titan Laboratori...      3.7           203
# 7         4300             Ican BPO      4.5           144
# 8         7268  Manav Rachna Int...      3.9            84
# 9         7958  Farmson Pharmace...      3.4            76
# 10        5265             Toyo INK      4.2           117
# 11        2292  Applied Material...      4.1           264
# 12        8494       Vtc Tradewings      4.0            71
# 13        4240        Ambit Finvest      4.1           147
# 14        7285       Delux Bearings      4.1            84
# 15        6111  High Court Luckn...      4.4           101
# 16        5118              SEForge      3.6           121
# 17        8613  Kalinga Universi...      3.4            70
# 18        3464      Damco Solutions      3.3           179
# 19         764              Tenneco      3.8           754
# 20        6280  Ministry of Home...      4.2            98
# 21        2549  adani power maha...      3.8           240
# 22        1721  Vedang Cellular ...      4.2           349
# 23        5286  Smiiel - A Unit ...      3.7           116
# 24        5555  Global Opportuni...      3.9           110
# 25         737  Sahara India Par...      3.8           783
# 26        1128   Collins Aerospa...      4.0           517
# 27        1513             DP World      4.0           397
# 28        1514  Offshore Infrast...      4.2           397
#
#                  ctype  years                                       hq  \
# 0               Public  106.0         New York City,New York + 17 more
# 1               Public   27.0  Bengaluru/Bangalore,Karnataka + 48 more
# 2              Private    8.0                      Ahmedabad + 30 more
# 3              Private   19.0             Bangalore,Karnataka + 8 more
# 4   Bengaluru + 2 more   18.0                                     None
# 5               Public   17.0                Delhi/NCR,Delhi + 31 more
# 6              Private   19.0             Mumbai,Maharashtra + 11 more
# 7              Private   14.0                           Thane + 2 more
# 8   Faridabad + 2 more   26.0                                     None
# 9    Vadodara + 5 more   53.0                                     None
# 10             Private   17.0                           Tokyo + 9 more
# 11             Private   21.0          Santa Clara,California + 9 more
# 12             Private   54.0                     Chandigarh + 14 more
# 13    Mumbai + 39 more    NaN                                     None
# 14     Mumbai + 8 more   67.0                                     None
# 15   Lucknow + 17 more    NaN                                     None
# 16             Private   17.0                      Coimbatore + 4 more
# 17     Raipur + 7 more   10.0                                     None
# 18             Private   27.0           Princeton,New Jersey + 15 more
# 19             Private   83.0           Lake Forest,Illinois + 28 more
# 20             Private   76.0                      New Delhi + 12 more
# 21    Mundra + 13 more    NaN                                      NaN
# 22    Mumbai + 48 more   13.0                                     None
# 23      Noida + 2 more   28.0                                     None
# 24             Private   22.0                Delhi/NCR,Delhi + 12 more
# 25             Private   45.0         Lucknow,Uttar Pradesh + 207 more
# 26             Private    5.0        Charlotte,North Carolina + 4 more
# 27              Public   18.0                Dubai,Jebel Ali + 40 more
# 28             Private   28.0             Mumbai,Maharashtra + 34 more
#
#                      employees  employees_clean
# 0     5k-10k Employees (India)           7500.0
# 1     5k-10k Employees (India)           7500.0
# 2     51-200 Employees (India)            125.5
# 3    201-500 Employees (India)            350.5
# 4                          NaN              NaN
# 5      1k-5k Employees (India)           3000.0
# 6    201-500 Employees (India)            350.5
# 7    201-500 Employees (India)            350.5
# 8                          NaN              NaN
# 9                          NaN              NaN
# 10     11-50 Employees (India)             30.5
# 11     1k-5k Employees (India)           3000.0
# 12    51-200 Employees (India)            125.5
# 13    51-200 Employees (India)            125.5
# 14                         NaN              NaN
# 15  201-500 Employees (Global)            350.5
# 16   201-500 Employees (India)            350.5
# 17                         NaN              NaN
# 18    501-1k Employees (India)            750.5
# 19     1k-5k Employees (India)           3000.0
# 20    51-200 Employees (India)            125.5
# 21                         NaN              NaN
# 22                         NaN              NaN
# 23                         NaN              NaN
# 24    51-200 Employees (India)            125.5
# 25    5k-10k Employees (India)           7500.0
# 26     1k-5k Employees (India)           3000.0
# 27     1k-5k Employees (India)           3000.0
# 28    501-1k Employees (India)            750.5

# %%
df[['employees', 'employees_clean']].head(10)
# Out:
#                    employees  employees_clean
# 0   5k-10k Employees (India)           7500.0
# 1   5k-10k Employees (India)           7500.0
# 2   51-200 Employees (India)            125.5
# 3  201-500 Employees (India)            350.5
# 4                        NaN              NaN
# 5    1k-5k Employees (India)           3000.0
# 6  201-500 Employees (India)            350.5
# 7  201-500 Employees (India)            350.5
# 8                        NaN              NaN
# 9                        NaN              NaN

# %%
df['years'].fillna(df['years'].mean(), inplace=True)
df['employees_clean'].fillna(df['employees_clean'].mean(), inplace=True)
df['ratings'].fillna(df['ratings'].mean(), inplace=True)

# %%
print("Average Rating:", df['ratings'].mean())
print("Total Reviews:", df['review_count'].sum())
print("Average Years:", df['years'].mean())
print("Average Employees:", df['employees_clean'].mean())
# Out:
# Average Rating: 3.944827586206897
# Total Reviews: 6005
# Average Years: 32.230769230769226
# Average Employees: 1971.9761904761906

# %%
df['hq'].fillna('Unknown', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0         0
# name               0
# ratings            0
# review_count       0
# ctype              0
# years              0
# hq                 0
# employees          8
# employees_clean    0
# dtype: int64

# %%
df
# Out:
#     Unnamed: 0                 name  ratings  review_count  \
# 0          268           S&P Global      4.2            18
# 1          512  Mercedes-Benz Re...      4.0            11
# 2         8520  Kifs Housing Fin...      3.6            70
# 3         2898             Algonomy      3.9           212
# 4         8767     Eurofins Advinus      3.8            68
# 5         3018     Religare Finvest      4.6           204
# 6         3033  Titan Laboratori...      3.7           203
# 7         4300             Ican BPO      4.5           144
# 8         7268  Manav Rachna Int...      3.9            84
# 9         7958  Farmson Pharmace...      3.4            76
# 10        5265             Toyo INK      4.2           117
# 11        2292  Applied Material...      4.1           264
# 12        8494       Vtc Tradewings      4.0            71
# 13        4240        Ambit Finvest      4.1           147
# 14        7285       Delux Bearings      4.1            84
# 15        6111  High Court Luckn...      4.4           101
# 16        5118              SEForge      3.6           121
# 17        8613  Kalinga Universi...      3.4            70
# 18        3464      Damco Solutions      3.3           179
# 19         764              Tenneco      3.8           754
# 20        6280  Ministry of Home...      4.2            98
# 21        2549  adani power maha...      3.8           240
# 22        1721  Vedang Cellular ...      4.2           349
# 23        5286  Smiiel - A Unit ...      3.7           116
# 24        5555  Global Opportuni...      3.9           110
# 25         737  Sahara India Par...      3.8           783
# 26        1128   Collins Aerospa...      4.0           517
# 27        1513             DP World      4.0           397
# 28        1514  Offshore Infrast...      4.2           397
#
#                  ctype       years                                       hq  \
# 0               Public  106.000000         New York City,New York + 17 more
# 1               Public   27.000000  Bengaluru/Bangalore,Karnataka + 48 more
# 2              Private    8.000000                      Ahmedabad + 30 more
# 3              Private   19.000000             Bangalore,Karnataka + 8 more
# 4   Bengaluru + 2 more   18.000000                                  Unknown
# 5               Public   17.000000                Delhi/NCR,Delhi + 31 more
# 6              Private   19.000000             Mumbai,Maharashtra + 11 more
# 7              Private   14.000000                           Thane + 2 more
# 8   Faridabad + 2 more   26.000000                                  Unknown
# 9    Vadodara + 5 more   53.000000                                  Unknown
# 10             Private   17.000000                           Tokyo + 9 more
# 11             Private   21.000000          Santa Clara,California + 9 more
# 12             Private   54.000000                     Chandigarh + 14 more
# 13    Mumbai + 39 more   32.230769                                  Unknown
# 14     Mumbai + 8 more   67.000000                                  Unknown
# 15   Lucknow + 17 more   32.230769                                  Unknown
# 16             Private   17.000000                      Coimbatore + 4 more
# 17     Raipur + 7 more   10.000000                                  Unknown
# 18             Private   27.000000           Princeton,New Jersey + 15 more
# 19             Private   83.000000           Lake Forest,Illinois + 28 more
# 20             Private   76.000000                      New Delhi + 12 more
# 21    Mundra + 13 more   32.230769                                  Unknown
# 22    Mumbai + 48 more   13.000000                                  Unknown
# 23      Noida + 2 more   28.000000                                  Unknown
# 24             Private   22.000000                Delhi/NCR,Delhi + 12 more
# 25             Private   45.000000         Lucknow,Uttar Pradesh + 207 more
# 26             Private    5.000000        Charlotte,North Carolina + 4 more
# 27              Public   18.000000                Dubai,Jebel Ali + 40 more
# 28             Private   28.000000             Mumbai,Maharashtra + 34 more
#
#                      employees  employees_clean
# 0     5k-10k Employees (India)       7500.00000
# 1     5k-10k Employees (India)       7500.00000
# 2     51-200 Employees (India)        125.50000
# 3    201-500 Employees (India)        350.50000
# 4                          NaN       1971.97619
# 5      1k-5k Employees (India)       3000.00000
# 6    201-500 Employees (India)        350.50000
# 7    201-500 Employees (India)        350.50000
# 8                          NaN       1971.97619
# 9                          NaN       1971.97619
# 10     11-50 Employees (India)         30.50000
# 11     1k-5k Employees (India)       3000.00000
# 12    51-200 Employees (India)        125.50000
# 13    51-200 Employees (India)        125.50000
# 14                         NaN       1971.97619
# 15  201-500 Employees (Global)        350.50000
# 16   201-500 Employees (India)        350.50000
# 17                         NaN       1971.97619
# 18    501-1k Employees (India)        750.50000
# 19     1k-5k Employees (India)       3000.00000
# 20    51-200 Employees (India)        125.50000
# 21                         NaN       1971.97619
# 22                         NaN       1971.97619
# 23                         NaN       1971.97619
# 24    51-200 Employees (India)        125.50000
# 25    5k-10k Employees (India)       7500.00000
# 26     1k-5k Employees (India)       3000.00000
# 27     1k-5k Employees (India)       3000.00000
# 28    501-1k Employees (India)        750.50000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset (if not already loaded)
# df = pd.read_csv('/content/cleaned_company_dataset.csv')

# Step 1: Create age groups
bins = [0, 10, 25, 50, 75, 100, 200]
labels = ['0-10', '10-25', '25-50', '50-75', '75-100', '100+']

df['year_group'] = pd.cut(df['years'], bins=bins, labels=labels)

# Step 2: Count companies in each group
year_counts = df['year_group'].value_counts().sort_index()

# Step 3: Plot pie chart
plt.figure(figsize=(7,7))

plt.pie(
    year_counts,
    labels=year_counts.index,
    autopct='%1.1f%%',
    startangle=140,
    explode=[0.05]*len(year_counts),  # optional highlight effect
    shadow=True
)

plt.title("Company Distribution by Years (Age Groups)")
plt.show()

# %%
from sympy import to_dnf

plt.figure(figsize=(10,6))

plt.barh(
    top_df['name'],
    top_df['review_count'],
    color='orange'
)

plt.xlabel("Reviews")
plt.title("Funnel Chart - Company Reviews")

plt.gca().invert_yaxis()

# Add values on barsS
for i, v in enumerate(top_df['review_count']):
    plt.text(v, i, str(v))

plt.show()

# %%
h=df[['name','hq']].head(10)
display(h)
# Out:
#                   name                                       hq
# 0           S&P Global         New York City,New York + 17 more
# 1  Mercedes-Benz Re...  Bengaluru/Bangalore,Karnataka + 48 more
# 2  Kifs Housing Fin...                      Ahmedabad + 30 more
# 3             Algonomy             Bangalore,Karnataka + 8 more
# 4     Eurofins Advinus                                  Unknown
# 5     Religare Finvest                Delhi/NCR,Delhi + 31 more
# 6  Titan Laboratori...             Mumbai,Maharashtra + 11 more
# 7             Ican BPO                           Thane + 2 more
# 8  Manav Rachna Int...                                  Unknown
# 9  Farmson Pharmace...                                  Unknown

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a DataFrame called df
# If not, first create it:
# df = pd.read_csv("your_file.csv")

# Clean company names for better plotting (optional but recommended)
df["name_short"] = df["name"].str.replace("...", "", regex=False)

# Sort by ratings for better visualization
df_sorted = df.sort_values(by="ratings", ascending=False)

plt.figure(figsize=(12,6))

plt.bar(df_sorted["name_short"], df_sorted["ratings"], color="skyblue")

plt.xticks(rotation=90)
plt.xlabel("Companies")
plt.ylabel("Ratings")
plt.title("Company Ratings Comparison")
plt.ylim(0, 5)  # since ratings are typically out of 5

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sort by employee count for better visual flow
df_sorted = df.sort_values(by='employees_clean')

plt.figure(figsize=(12,6))

plt.plot(df_sorted['name'], df_sorted['employees_clean'], marker='o')

plt.xticks(rotation=90)
plt.xlabel('Company Name')
plt.ylabel('Employees (Cleaned)')
plt.title('Employee Count Across Companies')
plt.grid(True)

plt.tight_layout()
plt.show()
